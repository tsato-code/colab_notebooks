# %% [markdown]
# <a href="https://colab.research.google.com/github/tsato-code/colab_notebooks/blob/main/plot_step.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(14)
y = np.sin(x / 2)

plt.step(x, y + 2, label='pre (default)')
plt.plot(x, y + 2, 'o--', color='grey', alpha=0.3)

plt.step(x, y + 1, where='mid', label='mid')
plt.plot(x, y + 1, 'o--', color='grey', alpha=0.3)

plt.step(x, y, where='post', label='post')
plt.plot(x, y, 'o--', color='grey', alpha=0.3)

plt.grid(axis='x', color='0.95')
plt.legend(title='Parameter where:')
plt.title('plt.step(where=...)')
plt.show()

# %%
# step関数を使わなくてもplotのオプションdrawstyleで同じ描画ができる
plt.plot(x, y + 2, drawstyle='steps', label='steps (=steps-pre)')
plt.plot(x, y + 2, 'o--', color='grey', alpha=0.3)

plt.plot(x, y + 1, drawstyle='steps-mid', label='steps-mid')
plt.plot(x, y + 1, 'o--', color='grey', alpha=0.3)

plt.plot(x, y, drawstyle='steps-post', label='steps-post')
plt.plot(x, y, 'o--', color='grey', alpha=0.3)

plt.grid(axis='x', color='0.95')
plt.legend(title='Parameter drawstyle:')
plt.title('plt.plot(drawstyle=...)')
plt.show()

# %%
# !wget https://zukan.pokemon.co.jp/zukan-api/up/images/index/7f4e7de4ad1f195877b85398cd66b0d5.jpg -O grimer.jpg
# !wget https://zukan.pokemon.co.jp/zukan-api/up/images/index/6055b042d11be9c582bcd4b660bc2dab.jpg -O psyduck.jpg
# Out:
# --2021-03-24 15:15:17--  https://zukan.pokemon.co.jp/zukan-api/up/images/index/7f4e7de4ad1f195877b85398cd66b0d5.jpg
# Resolving zukan.pokemon.co.jp (zukan.pokemon.co.jp)... 65.8.27.49, 65.8.27.25, 65.8.27.59, ...
# Connecting to zukan.pokemon.co.jp (zukan.pokemon.co.jp)|65.8.27.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 93392 (91K) [image/jpeg]
# Saving to: ‘grimer.jpg’
#
# grimer.jpg          100%[===================>]  91.20K  --.-KB/s    in 0.03s
#
# 2021-03-24 15:15:17 (2.86 MB/s) - ‘grimer.jpg’ saved [93392/93392]
#
# --2021-03-24 15:15:17--  https://zukan.pokemon.co.jp/zukan-api/up/images/index/6055b042d11be9c582bcd4b660bc2dab.jpg
# Resolving zukan.pokemon.co.jp (zukan.pokemon.co.jp)... 65.8.27.49, 65.8.27.25, 65.8.27.59, ...
# Connecting to zukan.pokemon.co.jp (zukan.pokemon.co.jp)|65.8.27.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98285 (96K) [image/jpeg]
# Saving to: ‘psyduck.jpg’
#
# ...

# %%
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig, ax = plt.subplots()

ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

poke01 = mpimg.imread('grimer.jpg')
poke02 = mpimg.imread('psyduck.jpg')

imagebox01 = OffsetImage(poke01, zoom=0.1)
imagebox02 = OffsetImage(poke02, zoom=0.1)

ab01 = AnnotationBbox(imagebox01, (0.2, 0.8))
ab02 = AnnotationBbox(imagebox02, (0.6, 0.2))

ax.add_artist(ab01)
ax.add_artist(ab02)

plt.grid()

plt.draw()
plt.savefig('add_picture_matplotlib_figure.png',bbox_inches='tight')
plt.show()
